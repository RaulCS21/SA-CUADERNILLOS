# %%
# EdA 1 - Python desde CERO
# Semana 2: Conociendo Google Colab

# =====================================
# CELDA 1: Bienvenida
# =====================================
print("Bienvenido a Google Colab")
print("Este será tu cuaderno de programación en Python")
# Out:
# Bienvenido a Google Colab
# Este será tu cuaderno de programación en Python

# %%
# =====================================
# CELDA 2: ¿Qué es una celda?
# =====================================
# Esta es una celda de código.
# Aquí escribimos instrucciones que Python ejecuta.

print("Estoy ejecutando mi primera celda de código")
# Out:
# Estoy ejecutando mi primera celda de código

# %%
# =====================================
# CELDA 3: Probando el botón ejecutar
# =====================================
print("Cuando presionas ejecutar, Python lee y obedece instrucciones")
# Out:
# Cuando presionas ejecutar, Python lee y obedece instrucciones

# %%
# =====================================
# CELDA 4: Reflexión
# =====================================
print("La programación empieza con instrucciones simples")
print("Pronto crearás tus propios programas")
# Out:
# La programación empieza con instrucciones simples
# Pronto crearás tus propios programas

# %%
# =====================================
# CELDA 5: Cierre
# =====================================
print("Has usado Google Colab correctamente")
print("En la siguiente clase escribirás tu primer programa")
# Out:
# Has usado Google Colab correctamente
# En la siguiente clase escribirás tu primer programa
